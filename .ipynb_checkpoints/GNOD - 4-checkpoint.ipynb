# %% [markdown]
# # Lab | Unsupervised learning intro (GNOD - part 4)

# %%
from bs4 import BeautifulSoup
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import requests
import pandas as pd
from pandas import json_normalize
import time
import random
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %%
#Import CSV Music Features

# %%
spotify_data = pd.read_csv('spotify_data.csv')

# %%
spotify_data
# Out:
#                                     title              artist  \
# 0                       Take Me To Church              Hozier
# 1             Cooler Than Me - Single Mix         Mike Posner
# 2        See You Again (feat. Kali Uchis)  Tyler, The Creator
# 3                                 Pompeii            Bastille
# 4      Hips Don't Lie (feat. Wyclef Jean)             Shakira
# ...                                   ...                 ...
# 11331            Jambalaya (On The Bayou)        John Fogerty
# 11332                     Hearts Of Stone        John Fogerty
# 11333                 Rock and Roll Girls        John Fogerty
# 11334          Rockin' All Over The World        John Fogerty
# 11335         Walking on the Chinese Wall       Philip Bailey
#
#                                         uri  danceability  energy  key  \
# 0      spotify:track:7dS5EaCoMnN7DzlpT6aRn2         0.566   0.664    4
# 1      spotify:track:2V4bv1fNWfTcyRJKmej6Sj         0.768   0.820    7
# 2      spotify:track:7KA4W4McWYRpgf0fWsJZWB         0.558   0.559    6
# 3      spotify:track:3gbBpTdY8lnQwqxNCcf795         0.679   0.715    9
# 4      spotify:track:3ZFTkvIE7kyPt6Nu3PEa7V         0.778   0.824   10
# ...                                     ...           ...     ...  ...
# 11331  spotify:track:6389cBCT7TWS2Nx0KVsjrk         0.742   0.756    2
# 11332  spotify:track:2uJVtJd1w2N8vg6pJmaNdN         0.412   0.677    6
# 11333  spotify:track:5DeuAlTIDflXOomztXYM5D         0.794   0.730    7
# 11334  spotify:track:2X0fwXZpoAbVZdyFVjJOUm         0.539   0.909    2
# 11335  spotify:track:0PXHA9nXcu4UOJFXvye9LE         0.488   0.862    1
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0        -5.303     0       0.0464        0.6340          0.000000    0.1160
# 1        -4.630     0       0.0474        0.1790          0.000000    0.6890
# 2        -9.222     1       0.0959        0.3710          0.000007    0.1090
# 3        -6.383     1       0.0407        0.0755          0.000000    0.2710
# 4        -5.892     0       0.0707        0.2840          0.000000    0.4050
# ...         ...   ...          ...           ...               ...       ...
# 11331   -10.121     1       0.0262        0.6240          0.000130    0.0800
# 11332   -10.763     1       0.0376        0.5370          0.006640    0.1210
# 11333    -6.067     1       0.0332        0.0538          0.000832    0.0826
# 11334    -6.546     1       0.0423        0.5180          0.000394    0.5580
# 11335    -7.653     0       0.0340        0.1690          0.025500    0.1780
#
#        valence    tempo            type                      id  \
# 0        0.437  128.945  audio_features  7dS5EaCoMnN7DzlpT6aRn2
# 1        0.625  129.965  audio_features  2V4bv1fNWfTcyRJKmej6Sj
# 2        0.620   78.558  audio_features  7KA4W4McWYRpgf0fWsJZWB
# 3        0.571  127.435  audio_features  3gbBpTdY8lnQwqxNCcf795
# 4        0.758  100.024  audio_features  3ZFTkvIE7kyPt6Nu3PEa7V
# ...        ...      ...             ...                     ...
# 11331    0.977   98.568  audio_features  6389cBCT7TWS2Nx0KVsjrk
# 11332    0.853  205.922  audio_features  2uJVtJd1w2N8vg6pJmaNdN
# 11333    0.767  128.999  audio_features  5DeuAlTIDflXOomztXYM5D
# 11334    0.964  130.821  audio_features  2X0fwXZpoAbVZdyFVjJOUm
# 11335    0.497  169.956  audio_features  0PXHA9nXcu4UOJFXvye9LE
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/7dS5EaCoMnN7...
# 1      https://api.spotify.com/v1/tracks/2V4bv1fNWfTc...
# 2      https://api.spotify.com/v1/tracks/7KA4W4McWYRp...
# 3      https://api.spotify.com/v1/tracks/3gbBpTdY8lnQ...
# 4      https://api.spotify.com/v1/tracks/3ZFTkvIE7kyP...
# ...                                                  ...
# 11331  https://api.spotify.com/v1/tracks/6389cBCT7TWS...
# 11332  https://api.spotify.com/v1/tracks/2uJVtJd1w2N8...
# 11333  https://api.spotify.com/v1/tracks/5DeuAlTIDflX...
# 11334  https://api.spotify.com/v1/tracks/2X0fwXZpoAbV...
# 11335  https://api.spotify.com/v1/tracks/0PXHA9nXcu4U...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/7dS5...       241688
# 1      https://api.spotify.com/v1/audio-analysis/2V4b...       213293
# 2      https://api.spotify.com/v1/audio-analysis/7KA4...       180387
# 3      https://api.spotify.com/v1/audio-analysis/3gbB...       214148
# 4      https://api.spotify.com/v1/audio-analysis/3ZFT...       218093
# ...                                                  ...          ...
# 11331  https://api.spotify.com/v1/audio-analysis/6389...       197760
# 11332  https://api.spotify.com/v1/audio-analysis/2uJV...       134000
# 11333  https://api.spotify.com/v1/audio-analysis/5Deu...       206640
# 11334  https://api.spotify.com/v1/audio-analysis/2X0f...       173000
# 11335  https://api.spotify.com/v1/audio-analysis/0PXH...       308773
#
#        time_signature
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 11331               4
# 11332               4
# 11333               4
# 11334               4
# 11335               4
#
# [11336 rows x 20 columns]

# %%
spotify_data.columns
# Out:
# Index(['title', 'artist', 'uri', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature'],
#       dtype='object')

# %%
X= spotify_data[['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness','valence', 'tempo']]

# %%
#Scale

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
#decide number of clusters

# %%
inertias = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X_scaled)
    inertias.append(kmeans.inertia_)

import matplotlib.pyplot as plt
plt.plot(range(1, 11), inertias, marker='o')
plt.xlabel('Número de clusters')
plt.ylabel('Inercia')
plt.show()

# %%
#build the model

# %%
kmeans = KMeans(n_clusters=8)
kmeans.fit(X_scaled)
# Out:
# KMeans()

# %%
clusters = kmeans.predict(X_scaled)

# %%
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    1687
# 1    1592
# 2    1146
# 3     634
# 4    2470
# 5    2663
# 6     765
# 7     379
# dtype: int64

# %%
#add cluster number to the songs

# %%
spotify_data['cluster'] = kmeans.predict(X_scaled)

# Muestra el dataframe con la nueva columna 'cluster'
print(spotify_data.head())
# Out:
#                                 title              artist  \
# 0                   Take Me To Church              Hozier
# 1         Cooler Than Me - Single Mix         Mike Posner
# 2    See You Again (feat. Kali Uchis)  Tyler, The Creator
# 3                             Pompeii            Bastille
# 4  Hips Don't Lie (feat. Wyclef Jean)             Shakira
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:7dS5EaCoMnN7DzlpT6aRn2         0.566   0.664    4    -5.303
# 1  spotify:track:2V4bv1fNWfTcyRJKmej6Sj         0.768   0.820    7    -4.630
# 2  spotify:track:7KA4W4McWYRpgf0fWsJZWB         0.558   0.559    6    -9.222
# 3  spotify:track:3gbBpTdY8lnQwqxNCcf795         0.679   0.715    9    -6.383
# 4  spotify:track:3ZFTkvIE7kyPt6Nu3PEa7V         0.778   0.824   10    -5.892
#
#    mode  speechiness  acousticness  ...  liveness  valence    tempo  \
# 0     0       0.0464        0.6340  ...     0.116    0.437  128.945
# 1     0       0.0474        0.1790  ...     0.689    0.625  129.965
# 2     1       0.0959        0.3710  ...     0.109    0.620   78.558
# 3     1       0.0407        0.0755  ...     0.271    0.571  127.435
# 4     0       0.0707        0.2840  ...     0.405    0.758  100.024
#
#              type                      id  \
# 0  audio_features  7dS5EaCoMnN7DzlpT6aRn2
# 1  audio_features  2V4bv1fNWfTcyRJKmej6Sj
# 2  audio_features  7KA4W4McWYRpgf0fWsJZWB
# 3  audio_features  3gbBpTdY8lnQwqxNCcf795
# 4  audio_features  3ZFTkvIE7kyPt6Nu3PEa7V
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7dS5EaCoMnN7...
# 1  https://api.spotify.com/v1/tracks/2V4bv1fNWfTc...
# 2  https://api.spotify.com/v1/tracks/7KA4W4McWYRp...
# 3  https://api.spotify.com/v1/tracks/3gbBpTdY8lnQ...
# 4  https://api.spotify.com/v1/tracks/3ZFTkvIE7kyP...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7dS5...      241688
# 1  https://api.spotify.com/v1/audio-analysis/2V4b...      213293
# 2  https://api.spotify.com/v1/audio-analysis/7KA4...      180387
# 3  https://api.spotify.com/v1/audio-analysis/3gbB...      214148
# 4  https://api.spotify.com/v1/audio-analysis/3ZFT...      218093
#
#    time_signature  cluster
# 0               4        4
# 1               4        3
# 2               4        1
# 3               4        5
# 4               4        4
#
# [5 rows x 21 columns]

# %%
spotify_data
# Out:
#                                     title              artist  \
# 0                       Take Me To Church              Hozier
# 1             Cooler Than Me - Single Mix         Mike Posner
# 2        See You Again (feat. Kali Uchis)  Tyler, The Creator
# 3                                 Pompeii            Bastille
# 4      Hips Don't Lie (feat. Wyclef Jean)             Shakira
# ...                                   ...                 ...
# 11331            Jambalaya (On The Bayou)        John Fogerty
# 11332                     Hearts Of Stone        John Fogerty
# 11333                 Rock and Roll Girls        John Fogerty
# 11334          Rockin' All Over The World        John Fogerty
# 11335         Walking on the Chinese Wall       Philip Bailey
#
#                                         uri  danceability  energy  key  \
# 0      spotify:track:7dS5EaCoMnN7DzlpT6aRn2         0.566   0.664    4
# 1      spotify:track:2V4bv1fNWfTcyRJKmej6Sj         0.768   0.820    7
# 2      spotify:track:7KA4W4McWYRpgf0fWsJZWB         0.558   0.559    6
# 3      spotify:track:3gbBpTdY8lnQwqxNCcf795         0.679   0.715    9
# 4      spotify:track:3ZFTkvIE7kyPt6Nu3PEa7V         0.778   0.824   10
# ...                                     ...           ...     ...  ...
# 11331  spotify:track:6389cBCT7TWS2Nx0KVsjrk         0.742   0.756    2
# 11332  spotify:track:2uJVtJd1w2N8vg6pJmaNdN         0.412   0.677    6
# 11333  spotify:track:5DeuAlTIDflXOomztXYM5D         0.794   0.730    7
# 11334  spotify:track:2X0fwXZpoAbVZdyFVjJOUm         0.539   0.909    2
# 11335  spotify:track:0PXHA9nXcu4UOJFXvye9LE         0.488   0.862    1
#
#        loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0        -5.303     0       0.0464        0.6340  ...    0.1160    0.437
# 1        -4.630     0       0.0474        0.1790  ...    0.6890    0.625
# 2        -9.222     1       0.0959        0.3710  ...    0.1090    0.620
# 3        -6.383     1       0.0407        0.0755  ...    0.2710    0.571
# 4        -5.892     0       0.0707        0.2840  ...    0.4050    0.758
# ...         ...   ...          ...           ...  ...       ...      ...
# 11331   -10.121     1       0.0262        0.6240  ...    0.0800    0.977
# 11332   -10.763     1       0.0376        0.5370  ...    0.1210    0.853
# 11333    -6.067     1       0.0332        0.0538  ...    0.0826    0.767
# 11334    -6.546     1       0.0423        0.5180  ...    0.5580    0.964
# 11335    -7.653     0       0.0340        0.1690  ...    0.1780    0.497
#
#          tempo            type                      id  \
# 0      128.945  audio_features  7dS5EaCoMnN7DzlpT6aRn2
# 1      129.965  audio_features  2V4bv1fNWfTcyRJKmej6Sj
# 2       78.558  audio_features  7KA4W4McWYRpgf0fWsJZWB
# 3      127.435  audio_features  3gbBpTdY8lnQwqxNCcf795
# 4      100.024  audio_features  3ZFTkvIE7kyPt6Nu3PEa7V
# ...        ...             ...                     ...
# 11331   98.568  audio_features  6389cBCT7TWS2Nx0KVsjrk
# 11332  205.922  audio_features  2uJVtJd1w2N8vg6pJmaNdN
# 11333  128.999  audio_features  5DeuAlTIDflXOomztXYM5D
# 11334  130.821  audio_features  2X0fwXZpoAbVZdyFVjJOUm
# 11335  169.956  audio_features  0PXHA9nXcu4UOJFXvye9LE
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/7dS5EaCoMnN7...
# 1      https://api.spotify.com/v1/tracks/2V4bv1fNWfTc...
# 2      https://api.spotify.com/v1/tracks/7KA4W4McWYRp...
# 3      https://api.spotify.com/v1/tracks/3gbBpTdY8lnQ...
# 4      https://api.spotify.com/v1/tracks/3ZFTkvIE7kyP...
# ...                                                  ...
# 11331  https://api.spotify.com/v1/tracks/6389cBCT7TWS...
# 11332  https://api.spotify.com/v1/tracks/2uJVtJd1w2N8...
# 11333  https://api.spotify.com/v1/tracks/5DeuAlTIDflX...
# 11334  https://api.spotify.com/v1/tracks/2X0fwXZpoAbV...
# 11335  https://api.spotify.com/v1/tracks/0PXHA9nXcu4U...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/7dS5...      241688
# 1      https://api.spotify.com/v1/audio-analysis/2V4b...      213293
# 2      https://api.spotify.com/v1/audio-analysis/7KA4...      180387
# 3      https://api.spotify.com/v1/audio-analysis/3gbB...      214148
# 4      https://api.spotify.com/v1/audio-analysis/3ZFT...      218093
# ...                                                  ...         ...
# 11331  https://api.spotify.com/v1/audio-analysis/6389...      197760
# 11332  https://api.spotify.com/v1/audio-analysis/2uJV...      134000
# 11333  https://api.spotify.com/v1/audio-analysis/5Deu...      206640
# 11334  https://api.spotify.com/v1/audio-analysis/2X0f...      173000
# 11335  https://api.spotify.com/v1/audio-analysis/0PXH...      308773
#
#        time_signature  cluster
# 0                   4        4
# 1                   4        3
# 2                   4        1
# 3                   4        5
# 4                   4        4
# ...               ...      ...
# 11331               4        1
# 11332               4        2
# 11333               4        5
# 11334               4        3
# 11335               4        2
#
# [11336 rows x 21 columns]

# %%
spotify_data.to_csv('spotify_data.csv', index=False)

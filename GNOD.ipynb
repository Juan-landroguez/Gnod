# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# 2. find url and store it in a variable

url = "http://www.popvortex.com/music/charts/top-100-songs.php"

# %%
# 3. download html with a get request

response = requests.get(url)
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")

# %%
# 4.2. check that the html code looks like it should
#soup

# %%
# 5. retrieve/extract the desired info (here, you'll paste the "Selector" you copied before to get the element that belongs to the top movie)
soup.select("#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p")
#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p > cite
# Out:
# [<p class="title-artist"><cite class="title">Last Night</cite><em class="artist">Morgan Wallen</em></p>]

# %%
soup.select("p cite")[0].get_text()
# Out:
# 'Last Night'

# %%
soup.select("p em")[0].get_text()
# Out:
# 'Morgan Wallen'

# %% [markdown]
# # Scrape the current top 100 songs and their respective artists, and put the information into a pandas dataframe.

# %%
title = []
band = []
num_iter = len(soup.select("p cite"))
ttitle = soup.select("p cite")
tband = soup.select("p em")
for i in range(num_iter):
    title.append(ttitle[i].get_text())
    band.append(tband[i].get_text())
    
#print(title)
print(band)
# Out:
# ['Morgan Wallen', 'Miley Cyrus', 'Russ', 'Luke Combs', 'Rema & Selena Gomez', 'Lainey Wilson', 'JISOO', 'Ed Sheeran', 'Taylor Swift', 'Lauren Daigle', 'Kane Brown & Katelyn Brown', 'Morgan Wallen', 'Morgan Wallen', 'Lauren Daigle', 'Coi Leray', 'SZA', 'P!nk', 'Charlie Puth', 'Blake Shelton', 'HARDY & Lainey Wilson', 'Bailey Zimmerman', 'Kaylee Rose', 'Toosii', 'Taylor Swift', 'Morgan Wallen', 'Luke Combs', 'LINKIN PARK', 'Jelly Roll', 'OneRepublic', 'Paid Pat', 'Sia', 'Luke Combs', 'Morgan Wallen', 'Miguel', 'Jimin', 'Jimin', 'Will Dempsey', 'Morgan Wallen', 'Chris Stapleton', 'Morgan Wallen', 'Rihanna', 'Zach Bryan', 'Jimin', 'Luke Combs', 'Jelly Roll', 'Harry Styles', 'Lauren Daigle', 'Rod Wave', 'Parker McCollum', 'Meghan Trainor', 'Sam Smith & Kim Petras', 'Jimin', 'Rema', 'Tyler Hubbard', 'Katy Nichole', 'JISOO', 'David Guetta & Bebe Rexha', 'PinkPantheress & Ice Spice', '6ix9ine & Lenier', 'Taylor Swift', 'LINKIN PARK', 'The Weeknd & Ariana Grande', 'RAYE & 070 Shake', 'Lauren Daigle', 'Lady Gaga', 'Meghan Trainor', 'Lady Gaga', 'Paris Paloma', 'KAROL G & Shakira', 'Megan Moroney', 'Fleetwood Mac', 'Darius Rucker', 'Ed Sheeran', 'Chris Isaak', 'Cody Johnson', 'Morgan Wallen', 'Taylor Swift', 'ROSALÍA & Rauw Alejandro', 'JVKE', 'Coco Jones', 'Dierks Bentley', 'Russ', 'Luke Combs', 'Jimin', 'Luke Combs', 'Katy Nichole & Big Daddy Weave', 'Tyler, The Creator', 'Dean Lewis', 'Morgan Wallen', 'Metro Boomin, The Weeknd & 21 Savage', 'Daisy Jones & The Six', 'Luke Combs', 'Melanie Martinez', 'Tracy Chapman', 'Josh Groban', 'Brandon Lake', 'Tiësto & Tate McRae', 'Morgan Wallen', 'Randy Travis', 'Tyler, The Creator']

# %%
# each list becomes a column
Topsongs = pd.DataFrame({"title":title,
                       "band":band,
                      })

# %%
Topsongs
# Out:
#                             title                 band
# 0                      Last Night        Morgan Wallen
# 1                         Flowers          Miley Cyrus
# 2        NASTY (Extended Version)                 Russ
# 3                        Fast Car           Luke Combs
# 4                       Calm Down  Rema & Selena Gomez
# ..                            ...                  ...
# 95                      Gratitude         Brandon Lake
# 96                          10:35  Tiësto & Tate McRae
# 97                Whiskey Glasses        Morgan Wallen
# 98         Forever and Ever, Amen         Randy Travis
# 99  WHARF TALK (feat. A$AP Rocky)   Tyler, The Creator
#
# [100 rows x 2 columns]

# %% [markdown]
# # Find other lists of hot songs on the internet and scrape them too: having a bigger pool of songs will be awesome!

# %%
# Top 100 Hip Hop & Rap Songs
#

# %%
# 2. find url and store it in a variable

url2 = "https://www.popvortex.com/music/charts/top-rap-songs.php"

# %%
# 3. download html with a get request

response2 = requests.get(url2)
response2.status_code # 200 status code means OK!
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup2 = BeautifulSoup(response2.content, "html.parser")

# %%
# 4.2. check that the html code looks like it should
#soup

# %%
# 5. retrieve/extract the desired info (here, you'll paste the "Selector" you copied before to get the element that belongs to the top movie)
soup2.select("#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p")
#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p > cite
# Out:
# [<p class="title-artist"><cite class="title">NASTY (Extended Version)</cite><em class="artist">Russ</em></p>]

# %%
soup2.select("p cite")[0].get_text()
soup2.select("p em")[0].get_text()
# Out:
# 'Russ'

# %%
title = []
band = []
num_iter = len(soup2.select("p cite"))
ttitle = soup2.select("p cite")
tband = soup2.select("p em")
for i in range(num_iter):
    title.append(ttitle[i].get_text())
    band.append(tband[i].get_text())
    
#print(title)
print(band)
# Out:
# ['Russ', 'Coi Leray', 'Toosii', 'Paid Pat', 'Rod Wave', 'Russ', 'Tyler, The Creator', 'Metro Boomin, The Weeknd & 21 Savage', 'Tyler, The Creator', 'Gucci Mane', 'Lil Uzi Vert', 'Latto', 'Tyler, The Creator', 'Tom MacDonald & John Rich', 'Coi Leray', 'Tyler, The Creator', 'Jelly Roll', 'Nicki Minaj', 'Tyler, The Creator', 'Big Boss Vette', 'Tyler, The Creator', 'Tyler, The Creator', 'DJ Drama & Moneybagg Yo', 'Eminem', 'Big Boss Vette', 'DJ Drama', 'Nicki Minaj, Xxtristanxo & Speed Radio', 'Larry June & The Alchemist', 'Larry June & The Alchemist', 'Vico C', '2Pac', 'NLE Choppa', 'Nardo Wick', 'Dr. Dre & Snoop Dogg', 'Post Malone & Swae Lee', 'Coolio', 'NF', 'Metro Boomin, Future & Chris Brown', 'Lil Uzi Vert', 'House of Pain', 'DJ Drama & Lil Wayne', '50 Cent', 'Drake & 21 Savage', 'Quavo', 'Lil Baby', 'Latto', 'Eminem', 'Cartel de Santa', 'Wiz Khalifa', 'Flo Rida', 'Post Malone', 'Lil Durk', 'Drake & 21 Savage', 'Lil Jon & The East Side Boyz & Ying Yang Twins', 'Vanilla Ice', 'DJ Drama, Wiz Khalifa & T.I.', 'Dax', 'Superstar Pride', 'NLE Choppa & Lil Wayne', 'Tyler, The Creator', 'Masked Wolf', 'Dr. Dre', 'Salt-N-Pepa', 'Metro Boomin, Future & Chris Brown', 'Eminem', 'Post Malone', 'Nicki Minaj', 'Don Zio P', 'Macklemore & Ryan Lewis', 'Saweetie', 'Eminem', 'Armani White & Denzel Curry', 'Doechii', 'BigXthaPlug', 'DJ Khaled', 'Fugees', 'Montell Jordan', 'Salt-N-Pepa', 'Masked Wolf', 'Nipsey Hussle', 'Icandy', 'Lola Brooke', 'NF', 'Latto', 'Doechii', 'Ice Spice', 'Ren', 'DJ Drama', 'Ice Cube', 'Cardi B', 'Beastie Boys', 'Too $hort', 'Nicki Minaj', 'NF', 'Juice WRLD', 'Outkast', 'The Sugarhill Gang', 'Lecrae & Andy Mineo', 'Latto & Mariah Carey', 'Beastie Boys']

# %%
# each list becomes a column
Topsongs2 = pd.DataFrame({"title":title,
                       "band":band,
                      })

# %%
# Top 100 Pop Songs
#

# %%
# 2. find url and store it in a variable

url3 = "https://www.popvortex.com/music/charts/top-pop-songs.php"

# %%
# 3. download html with a get request

response3 = requests.get(url3)
response3.status_code # 200 status code means OK!
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup3 = BeautifulSoup(response3.content, "html.parser")

# %%
# 4.2. check that the html code looks like it should
#soup

# %%
# 5. retrieve/extract the desired info (here, you'll paste the "Selector" you copied before to get the element that belongs to the top movie)
soup3.select("#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p")
#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p > cite
# Out:
# [<p class="title-artist"><cite class="title">Flowers</cite><em class="artist">Miley Cyrus</em></p>]

# %%
soup3.select("p cite")[0].get_text()
soup3.select("p em")[0].get_text()
# Out:
# 'Miley Cyrus'

# %%
title = []
band = []
num_iter = len(soup3.select("p cite"))
ttitle = soup3.select("p cite")
tband = soup3.select("p em")
for i in range(num_iter):
    title.append(ttitle[i].get_text())
    band.append(tband[i].get_text())
    
#print(title)
print(band)
# Out:
# ['Miley Cyrus', 'Rema & Selena Gomez', 'JISOO', 'Ed Sheeran', 'Taylor Swift', 'Lauren Daigle', 'P!nk', 'Charlie Puth', 'Taylor Swift', 'OneRepublic', 'Sia', 'Jimin', 'Jimin', 'Rihanna', 'Jimin', 'Harry Styles', 'Meghan Trainor', 'Sam Smith & Kim Petras', 'Jimin', 'JISOO', 'PinkPantheress & Ice Spice', 'Taylor Swift', 'RAYE & 070 Shake', 'Lady Gaga', 'Meghan Trainor', 'Lady Gaga', 'Ed Sheeran', 'Chris Isaak', 'Taylor Swift', 'JVKE', 'Jimin', 'Josh Groban', 'Lizzo', 'Niall Horan', 'Ed Sheeran', 'Taylor Swift', 'Ed Sheeran', 'Elton John & Dua Lipa', 'P!nk', 'Ava Max', 'Miley Cyrus', 'Rick Astley', 'Michael Giacchino', 'Nicky Youre & Dazy', 'P!nk', 'Taylor Swift', 'Miley Cyrus', 'James Blunt', 'Taylor Swift', 'Avril Lavigne', 'Taylor Swift', 'Jimin', 'Jax', 'Lauren Daigle', 'Taylor Swift', 'Cian Ducrot', 'Harry Styles', 'Tears for Fears', 'ABBA', 'Song House & Wé Ani', 'Justin Bieber', 'John Denver', 'Taylor Swift', 'Adele', 'Beyoncé', 'Bebe Rexha', 'Taylor Swift', 'Sam Smith & Kim Petras', 'P!nk', 'Jax', 'Miley Cyrus', 'Eurythmics', 'Nathan Evans', 'Lizzo', 'Miley Cyrus', 'Harry Styles', 'Mark Morrison', 'Lizzo', 'Taylor Swift', 'Taylor Swift', 'The Kid LAROI', 'Taylor Swift', 'Miley Cyrus', 'Harry Styles', 'GAYLE', 'Adele', 'P!nk', 'Ed Sheeran', 'Mark Ronson', 'Lizzo', 'Taylor Swift', 'Forest Blakk', 'The Animals', 'Neil Diamond', 'Beyoncé', 'P!nk', 'a-ha', 'Harry Styles', 'Selena Gomez', 'Taylor Swift']

# %%
# each list becomes a column
Topsongs3 = pd.DataFrame({"title":title,
                       "band":band,
                      })
Topsongs3
# Out:
#                   title                 band
# 0               Flowers          Miley Cyrus
# 1             Calm Down  Rema & Selena Gomez
# 2                FLOWER                JISOO
# 3           Eyes Closed           Ed Sheeran
# 4             Anti-Hero         Taylor Swift
# ..                  ...                  ...
# 95        What About Us                 P!nk
# 96           Take On Me                 a-ha
# 97            Adore You         Harry Styles
# 98  Lose You to Love Me         Selena Gomez
# 99                Style         Taylor Swift
#
# [100 rows x 2 columns]

# %%
# Top 100 Country Songs
#

# %%
# 2. find url and store it in a variable

url4 = "https://www.popvortex.com/music/charts/top-country-songs.php"

# %%
# 3. download html with a get request

response4 = requests.get(url4)
response4.status_code # 200 status code means OK!
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup4 = BeautifulSoup(response4.content, "html.parser")

# %%
# 4.2. check that the html code looks like it should
#soup

# %%
# 5. retrieve/extract the desired info (here, you'll paste the "Selector" you copied before to get the element that belongs to the top movie)
soup4.select("#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p")
#chart-position-1 > div.chart-content.col-xs-12.col-sm-8 > p > cite
# Out:
# [<p class="title-artist"><cite class="title">Last Night</cite><em class="artist">Morgan Wallen</em></p>]

# %%
soup4.select("p cite")[0].get_text()
soup4.select("p em")[0].get_text()
# Out:
# 'Morgan Wallen'

# %%
title = []
band = []
num_iter = len(soup4.select("p cite"))
ttitle = soup4.select("p cite")
tband = soup4.select("p em")
for i in range(num_iter):
    title.append(ttitle[i].get_text())
    band.append(tband[i].get_text())
    
#print(title)
print(band)
# Out:
# ['Morgan Wallen', 'Luke Combs', 'Lainey Wilson', 'Kane Brown & Katelyn Brown', 'Morgan Wallen', 'Morgan Wallen', 'Blake Shelton', 'HARDY & Lainey Wilson', 'Bailey Zimmerman', 'Kaylee Rose', 'Morgan Wallen', 'Luke Combs', 'Jelly Roll', 'Luke Combs', 'Morgan Wallen', 'Will Dempsey', 'Morgan Wallen', 'Chris Stapleton', 'Morgan Wallen', 'Zach Bryan', 'Luke Combs', 'Parker McCollum', 'Tyler Hubbard', 'Megan Moroney', 'Darius Rucker', 'Cody Johnson', 'Morgan Wallen', 'Dierks Bentley', 'Luke Combs', 'Luke Combs', 'Morgan Wallen', 'Luke Combs', 'Morgan Wallen', 'Randy Travis', 'Blake Shelton', 'Cole Swindell', 'Morgan Wallen', 'Lil Nas X', 'Carly Pearce', 'HARDY', 'Corey Kent', 'Morgan Wallen', 'Kelsea Ballerini', 'Cody Johnson', 'Morgan Wallen', 'Tim McGraw', 'Zach Bryan', 'Cole Swindell', 'Jordan Davis', 'Drake Milligan', 'Warren Zeiders', 'Old Dominion', 'Kane Brown', 'Lainey Wilson', 'Morgan Wallen', 'Steel Bill & OBN Jay', 'Chris Stapleton', 'Morgan Wallen', 'Chris Stapleton', 'Chris Stapleton', 'Walker Hayes', 'Lainey Wilson', 'Scotty McCreery', 'Randy Travis', 'Bryan Martin', 'Taylor Swift', 'Bailey Zimmerman', 'Brett Young', 'Kelsea Ballerini', 'Dolly Parton & Kenny Rogers', 'Cole Swindell & Lainey Wilson', 'Nate Smith', 'Drew Baldridge', 'Luke Combs', 'Morgan Wallen', 'HARDY', 'David J', 'Luke Combs', 'Randy Travis', 'Darius Rucker', 'Taylor Swift', 'LECADE', 'Justin Moore & Riley Green', 'Jordan Davis', 'Zach Bryan', 'Zach Bryan', 'Chris Stapleton', 'HARDY', 'Lainey Wilson', 'Ashley McBryde', 'Morgan Wallen', 'Elle King', 'Luke Combs', 'Morgan Wallen', 'Jordan Davis', 'Larry Fleet', 'Keith Urban', 'Taylor Swift', 'Jon Pardi', 'Josh Ross']

# %%
# each list becomes a column
Topsongs4 = pd.DataFrame({"title":title,
                       "band":band,
                      })

# %%
Topsongs4
# Out:
#                                     title                        band
# 0                              Last Night               Morgan Wallen
# 1                                Fast Car                  Luke Combs
# 2                      Heart Like A Truck               Lainey Wilson
# 3                               Thank God  Kane Brown & Katelyn Brown
# 4                 Thought You Should Know               Morgan Wallen
# ..                                    ...                         ...
# 95                       Where I Find God                 Larry Fleet
# 96                        Brown Eyes Baby                 Keith Urban
# 97  You Belong With Me (Taylor’s Version)                Taylor Swift
# 98                     Your Heart Or Mine                   Jon Pardi
# 99                                Trouble                   Josh Ross
#
# [100 rows x 2 columns]

# %%
hot_songs = Topsongs.append(Topsongs2, ignore_index=True)
hot_songs
# Out:
# /var/folders/0r/l856hq9x61zf5p8g8vxjs_dh0000gn/T/ipykernel_2184/3172745948.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hot_songs = Topsongs.append(Topsongs2, ignore_index=True)
#                                     title                  band
# 0                              Last Night         Morgan Wallen
# 1                                 Flowers           Miley Cyrus
# 2                NASTY (Extended Version)                  Russ
# 3                                Fast Car            Luke Combs
# 4                               Calm Down   Rema & Selena Gomez
# ..                                    ...                   ...
# 195                           Ms. Jackson               Outkast
# 196  Rapper's Delight (7" Single Version)    The Sugarhill Gang
# 197                         Coming in Hot   Lecrae & Andy Mineo
# 198  Big Energy (Remix) [feat. DJ Khaled]  Latto & Mariah Carey
# 199                          Brass Monkey          Beastie Boys
#
# [200 rows x 2 columns]

# %%
hot_songs = hot_songs.append(Topsongs3, ignore_index=True)
hot_songs
# Out:
# /var/folders/0r/l856hq9x61zf5p8g8vxjs_dh0000gn/T/ipykernel_2184/611984416.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hot_songs = hot_songs.append(Topsongs3, ignore_index=True)
#                         title                 band
# 0                  Last Night        Morgan Wallen
# 1                     Flowers          Miley Cyrus
# 2    NASTY (Extended Version)                 Russ
# 3                    Fast Car           Luke Combs
# 4                   Calm Down  Rema & Selena Gomez
# ..                        ...                  ...
# 295             What About Us                 P!nk
# 296                Take On Me                 a-ha
# 297                 Adore You         Harry Styles
# 298       Lose You to Love Me         Selena Gomez
# 299                     Style         Taylor Swift
#
# [300 rows x 2 columns]

# %%
hot_songs = hot_songs.append(Topsongs4, ignore_index=True)
hot_songs
# Out:
# /var/folders/0r/l856hq9x61zf5p8g8vxjs_dh0000gn/T/ipykernel_2184/3502223172.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hot_songs = hot_songs.append(Topsongs4, ignore_index=True)
#                                      title                 band
# 0                               Last Night        Morgan Wallen
# 1                                  Flowers          Miley Cyrus
# 2                 NASTY (Extended Version)                 Russ
# 3                                 Fast Car           Luke Combs
# 4                                Calm Down  Rema & Selena Gomez
# ..                                     ...                  ...
# 395                       Where I Find God          Larry Fleet
# 396                        Brown Eyes Baby          Keith Urban
# 397  You Belong With Me (Taylor’s Version)         Taylor Swift
# 398                     Your Heart Or Mine            Jon Pardi
# 399                                Trouble            Josh Ross
#
# [400 rows x 2 columns]

# %%
hot_songs = hot_songs.rename(columns={'band': 'artist'})

# %%
hot_songs
# Out:
#                                      title               artist
# 0                               Last Night        Morgan Wallen
# 1                                  Flowers          Miley Cyrus
# 2                 NASTY (Extended Version)                 Russ
# 3                                 Fast Car           Luke Combs
# 4                                Calm Down  Rema & Selena Gomez
# ..                                     ...                  ...
# 395                       Where I Find God          Larry Fleet
# 396                        Brown Eyes Baby          Keith Urban
# 397  You Belong With Me (Taylor’s Version)         Taylor Swift
# 398                     Your Heart Or Mine            Jon Pardi
# 399                                Trouble            Josh Ross
#
# [400 rows x 2 columns]

# %%
hot_songs.to_csv('hot_songs.csv', index=False)

# %% [markdown]
# # Today you are creating a recommender where the user inputs a song title and check if that song is in the list you created.   If it is,  give a different random song and artist from the list.  If it is not on the list, let the user know that you have no recommendation at this time.

# %%
your_song = input("write down your song: ")
your_artist = input("write down your artist: ")

# %%
recommendation = hot_songs.sample(n=1)
recommendation

# %%
if len(hot_songs[(hot_songs['band'] == your_artist) & (hot_songs['title'] == your_song)]) == 1:
    print (recommendation)
else:
    print ("Ups, your request didn't works. Try again!")

# %% [markdown]
# # Lab | API wrappers - Create your collection of songs & audio features

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from pandas import json_normalize
import requests
from bs4 import BeautifulSoup
import time
import random

# %%
# Playslists selected: 4rnleEAOdmFAbRcNCgZMpY , 5S8SJdl1BDc0ugpkEvFsIL

# %%
secrets_file = open("secrets.txt","r")
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['CID'],
                                                           client_secret=secrets_dict['Csecret']))

# %%
# Audio features

# %%
playlist_id = ['4rnleEAOdmFAbRcNCgZMpY',
               '37i9dQZF1DWTmvXBN4DgpA','5DPT4gtwr5AeFlf3YVvdmK','4RVf1hHtwvMEED3yuCNi8q']

# %%
playlist1 = sp.user_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")
playlist2 = sp.user_playlist_tracks("spotify", "37i9dQZF1DWTmvXBN4DgpA")
playlist3 = sp.user_playlist_tracks("spotify", "5DPT4gtwr5AeFlf3YVvdmK")
playlist4 = sp.user_playlist_tracks("spotify", "4RVf1hHtwvMEED3yuCNi8q")

# %%
display(type(playlist1), playlist1['total'])
display(type(playlist2), playlist2['total'])
display(type(playlist3), playlist3['total'])
display(type(playlist4), playlist4['total'])
# Out:
# dict
# 5295
# dict
# 1999
# dict
# 2705
# dict
# 3318

# %%
# Checking the path to get 'title', 'artist' and 'uri'
display(playlist1["items"][0]["track"]["name"]) # title
display(playlist1["items"][0]["track"]["artists"][0]["name"]) # artist
display(playlist1["items"][0]["track"]["uri"]) # uri
# Out:
# 'Take Me To Church'
# 'Hozier'
# 'spotify:track:7dS5EaCoMnN7DzlpT6aRn2'

# %%
# Retrieving all data from playlists and creating a new dataframe

# %%
playlists_list = ["playlist1","playlist2","playlist3","playlist4"]

# %%
# Function to retrieve ALL data of "title", "artist", and "uri" 's id and metrics

def create_playlist_dataframe(playlist, sp):
    # List of items in track
    tracks = []
    
    # While there is a next page of results in the playlist
    while playlist:
        # For each item in playlist:
        for item in playlist['items']:
            # Look for uri and save id and get values in features
            song_uri = item['track']['uri']
            features = sp.audio_features(song_uri)[0]
            
            # New dict retrieving values of 'title', 'artist' and 'uri' (id)
            track = {
                'title': item['track']['name'],
                'artist': item['track']['artists'][0]['name'],
                'uri': song_uri,
            }
            
            # for each feature add in track dict the key (column name) and the value
            for feature_key, feature_value in features.items():
                track[feature_key] = feature_value
                
            # Append each item in track
            tracks.append(track)
        
        # Get the next page of results
        playlist = sp.next(playlist)
        
        # Sleep for a random time between 1 and 3 seconds to avoid triggering rate limits
        sleep_time = random.randint(1, 3)
        time.sleep(sleep_time)
    
    # Return the results as a DataFrame
    return pd.DataFrame(tracks)

# %%
# Applying the function
playlist1_df = create_playlist_dataframe(playlist1, sp)

# %%
display(playlist1_df.head(5), playlist1_df.shape)
# Out:
#                                 title              artist  \
# 0                   Take Me To Church              Hozier
# 1         Cooler Than Me - Single Mix         Mike Posner
# 2    See You Again (feat. Kali Uchis)  Tyler, The Creator
# 3                             Pompeii            Bastille
# 4  Hips Don't Lie (feat. Wyclef Jean)             Shakira
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:7dS5EaCoMnN7DzlpT6aRn2         0.566   0.664    4    -5.303
# 1  spotify:track:2V4bv1fNWfTcyRJKmej6Sj         0.768   0.820    7    -4.630
# 2  spotify:track:7KA4W4McWYRpgf0fWsJZWB         0.558   0.559    6    -9.222
# 3  spotify:track:3gbBpTdY8lnQwqxNCcf795         0.679   0.715    9    -6.383
# 4  spotify:track:3ZFTkvIE7kyPt6Nu3PEa7V         0.778   0.824   10    -5.892
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.0464        0.6340          0.000000     0.116    0.437
# 1     0       0.0474        0.1790          0.000000     0.689    0.625
# 2     1       0.0959        0.3710          0.000007     0.109    0.620
# 3     1       0.0407        0.0755          0.000000     0.271    0.571
# 4     0       0.0707        0.2840          0.000000     0.405    0.758
#
#      tempo            type                      id  \
# 0  128.945  audio_features  7dS5EaCoMnN7DzlpT6aRn2
# 1  129.965  audio_features  2V4bv1fNWfTcyRJKmej6Sj
# 2   78.558  audio_features  7KA4W4McWYRpgf0fWsJZWB
# 3  127.435  audio_features  3gbBpTdY8lnQwqxNCcf795
# 4  100.024  audio_features  3ZFTkvIE7kyPt6Nu3PEa7V
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7dS5EaCoMnN7...
# 1  https://api.spotify.com/v1/tracks/2V4bv1fNWfTc...
# 2  https://api.spotify.com/v1/tracks/7KA4W4McWYRp...
# 3  https://api.spotify.com/v1/tracks/3gbBpTdY8lnQ...
# 4  https://api.spotify.com/v1/tracks/3ZFTkvIE7kyP...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7dS5...       241688
# 1  https://api.spotify.com/v1/audio-analysis/2V4b...       213293
# 2  https://api.spotify.com/v1/audio-analysis/7KA4...       180387
# 3  https://api.spotify.com/v1/audio-analysis/3gbB...       214148
# 4  https://api.spotify.com/v1/audio-analysis/3ZFT...       218093
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# (5295, 20)

# %%
playlist2_df = create_playlist_dataframe(playlist2, sp)

# %%
display(playlist2_df.head(5), playlist2_df.shape)
# Out:
#                                  title      artist  \
# 0  Bohemian Rhapsody - Remastered 2011       Queen
# 1                       Roller Coaster  Danny Vera
# 2     Hotel California - 2013 Remaster      Eagles
# 3                            Piano Man  Billy Joel
# 4                              Fix You    Coldplay
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:7tFiyTwD0nx5a1eklYtX2J         0.392   0.402    0    -9.961
# 1  spotify:track:5B5YKjgne3TZzNpMsN9aj1         0.401   0.383    9   -10.048
# 2  spotify:track:40riOy7x9W7GXjyGp4pjAv         0.579   0.508    2    -9.484
# 3  spotify:track:3FCto7hnn1shUyZL42YgfO         0.334   0.472    0    -8.791
# 4  spotify:track:7LVHVU3tWfcxj5aiPFEW4Q         0.209   0.417    3    -8.740
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.0536       0.28800          0.000000    0.2430    0.228
# 1     1       0.0279       0.51000          0.007800    0.1210    0.285
# 2     1       0.0270       0.00574          0.000494    0.0575    0.609
# 3     1       0.0277       0.60000          0.000004    0.3170    0.431
# 4     1       0.0338       0.16400          0.001960    0.1130    0.124
#
#      tempo            type                      id  \
# 0  143.883  audio_features  7tFiyTwD0nx5a1eklYtX2J
# 1   96.957  audio_features  5B5YKjgne3TZzNpMsN9aj1
# 2  147.125  audio_features  40riOy7x9W7GXjyGp4pjAv
# 3  179.173  audio_features  3FCto7hnn1shUyZL42YgfO
# 4  138.178  audio_features  7LVHVU3tWfcxj5aiPFEW4Q
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7tFiyTwD0nx5...
# 1  https://api.spotify.com/v1/tracks/5B5YKjgne3TZ...
# 2  https://api.spotify.com/v1/tracks/40riOy7x9W7G...
# 3  https://api.spotify.com/v1/tracks/3FCto7hnn1sh...
# 4  https://api.spotify.com/v1/tracks/7LVHVU3tWfcx...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7tFi...       354320
# 1  https://api.spotify.com/v1/audio-analysis/5B5Y...       269986
# 2  https://api.spotify.com/v1/audio-analysis/40ri...       391376
# 3  https://api.spotify.com/v1/audio-analysis/3FCt...       336093
# 4  https://api.spotify.com/v1/audio-analysis/7LVH...       295533
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               3
# 4               4
# (1999, 20)

# %%
playlist3_df = create_playlist_dataframe(playlist3, sp)

# %%
display(playlist3_df.head(5), playlist3_df.shape)
# Out:
#                                           title           artist  \
# 0                              Rhapsody in Blue  George Gershwin
# 1                                    Summertime   Billie Holiday
# 2  Moonlight Serenade - 2005 Remastered Version     Glenn Miller
# 3                            In the Mood - Live     Glenn Miller
# 4                            Take the "A" Train   Duke Ellington
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:0yzhOPf0iw2qWwcXRRta5L         0.309   0.258    9   -15.327
# 1  spotify:track:62Xj6x2LSWv47PtRAXrg5Z         0.628   0.226   10   -14.075
# 2  spotify:track:3HRMOZk689zaR3z6NpEdfu         0.228   0.263    3   -10.120
# 3  spotify:track:54h1RKrrFJDsNOfhwmqu9o         0.463   0.654    8    -9.720
# 4  spotify:track:6KBsivP3Of4z2x6uNMAyE3         0.479   0.318    0   -13.836
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0459         0.976          0.690000    0.0924    0.115
# 1     0       0.0371         0.903          0.000006    0.1710    0.608
# 2     1       0.0275         0.896          0.317000    0.1030    0.224
# 3     1       0.0659         0.824          0.917000    0.3720    0.592
# 4     1       0.0395         0.278          0.095900    0.1070    0.575
#
#      tempo            type                      id  \
# 0   74.568  audio_features  0yzhOPf0iw2qWwcXRRta5L
# 1   99.392  audio_features  62Xj6x2LSWv47PtRAXrg5Z
# 2   83.903  audio_features  3HRMOZk689zaR3z6NpEdfu
# 3  175.204  audio_features  54h1RKrrFJDsNOfhwmqu9o
# 4   94.036  audio_features  6KBsivP3Of4z2x6uNMAyE3
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0yzhOPf0iw2q...
# 1  https://api.spotify.com/v1/tracks/62Xj6x2LSWv4...
# 2  https://api.spotify.com/v1/tracks/3HRMOZk689za...
# 3  https://api.spotify.com/v1/tracks/54h1RKrrFJDs...
# 4  https://api.spotify.com/v1/tracks/6KBsivP3Of4z...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0yzh...       890000
# 1  https://api.spotify.com/v1/audio-analysis/62Xj...       173493
# 2  https://api.spotify.com/v1/audio-analysis/3HRM...       204240
# 3  https://api.spotify.com/v1/audio-analysis/54h1...       209573
# 4  https://api.spotify.com/v1/audio-analysis/6KBs...       331800
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# (2705, 20)

# %%
playlist4_df = create_playlist_dataframe(playlist4, sp)

# %%
display(playlist4_df.head(5), playlist4_df.shape)
# Out:
#                                                title              artist  \
# 0                            Angie - Remastered 2009  The Rolling Stones
# 1                                        Billie Jean     Michael Jackson
# 2                         Hey Jude - Remastered 2015         The Beatles
# 3                                        Purple Rain              Prince
# 4  I Heard It Through The Grapevine - Single Vers...         Marvin Gaye
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:35RUp1t6MVhcG8cOK5BH6x         0.429   0.548    9    -6.017
# 1  spotify:track:5ChkMS8OtdzJeqyybCc9R5         0.920   0.654   11    -3.051
# 2  spotify:track:0aym2LBJBk9DAYuHHutrIl         0.386   0.607   10    -7.700
# 3  spotify:track:3lUjT0JcV1PcuugwMl2MQj         0.367   0.452   10   -10.422
# 4  spotify:track:6ca3m7gXDEfgLop4A51mWt         0.722   0.450    3    -7.503
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.0294        0.7000          0.000075    0.0836    0.383
# 1     0       0.0401        0.0236          0.015300    0.0360    0.847
# 2     1       0.0261        0.0112          0.000014    0.0880    0.532
# 3     1       0.0307        0.0353          0.002280    0.6890    0.189
# 4     0       0.0396        0.1990          0.000003    0.0739    0.664
#
#      tempo            type                      id  \
# 0  138.619  audio_features  35RUp1t6MVhcG8cOK5BH6x
# 1  117.046  audio_features  5ChkMS8OtdzJeqyybCc9R5
# 2  147.207  audio_features  0aym2LBJBk9DAYuHHutrIl
# 3  113.066  audio_features  3lUjT0JcV1PcuugwMl2MQj
# 4  118.447  audio_features  6ca3m7gXDEfgLop4A51mWt
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/35RUp1t6MVhc...
# 1  https://api.spotify.com/v1/tracks/5ChkMS8OtdzJ...
# 2  https://api.spotify.com/v1/tracks/0aym2LBJBk9D...
# 3  https://api.spotify.com/v1/tracks/3lUjT0JcV1Pc...
# 4  https://api.spotify.com/v1/tracks/6ca3m7gXDEfg...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/35RU...       271973
# 1  https://api.spotify.com/v1/audio-analysis/5Chk...       293827
# 2  https://api.spotify.com/v1/audio-analysis/0aym...       425653
# 3  https://api.spotify.com/v1/audio-analysis/3lUj...       520787
# 4  https://api.spotify.com/v1/audio-analysis/6ca3...       192267
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
# (3318, 20)

# %%
# Checking if df are ready for concatenation

# %%
df_list = ["playlist1_df","playlist2_df","playlist3_df","playlist4_df"]

# %%
# Checking same names and order for each dataframe's columns
display(playlist1_df.columns == playlist2_df.columns, playlist1_df.columns == playlist3_df.columns, playlist1_df.columns == playlist4_df.columns)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True])

# %%
# Information about their shape
display(playlist1_df.shape, playlist2_df.shape, playlist3_df.shape, playlist4_df.shape)
# Out:
# (5295, 20)
# (1999, 20)
# (2705, 20)
# (3318, 20)

# %%
# Concatenating in axis=0 (rows)
spotify_data = pd.concat([playlist1_df, playlist2_df, playlist3_df, playlist4_df], axis = 0)

# %%
spotify_data
# Out:
#                                    title              artist  \
# 0                      Take Me To Church              Hozier
# 1            Cooler Than Me - Single Mix         Mike Posner
# 2       See You Again (feat. Kali Uchis)  Tyler, The Creator
# 3                                Pompeii            Bastille
# 4     Hips Don't Lie (feat. Wyclef Jean)             Shakira
# ...                                  ...                 ...
# 3313            Jambalaya (On The Bayou)        John Fogerty
# 3314                     Hearts Of Stone        John Fogerty
# 3315                 Rock and Roll Girls        John Fogerty
# 3316          Rockin' All Over The World        John Fogerty
# 3317         Walking on the Chinese Wall       Philip Bailey
#
#                                        uri  danceability  energy  key  \
# 0     spotify:track:7dS5EaCoMnN7DzlpT6aRn2         0.566   0.664    4
# 1     spotify:track:2V4bv1fNWfTcyRJKmej6Sj         0.768   0.820    7
# 2     spotify:track:7KA4W4McWYRpgf0fWsJZWB         0.558   0.559    6
# 3     spotify:track:3gbBpTdY8lnQwqxNCcf795         0.679   0.715    9
# 4     spotify:track:3ZFTkvIE7kyPt6Nu3PEa7V         0.778   0.824   10
# ...                                    ...           ...     ...  ...
# 3313  spotify:track:6389cBCT7TWS2Nx0KVsjrk         0.742   0.756    2
# 3314  spotify:track:2uJVtJd1w2N8vg6pJmaNdN         0.412   0.677    6
# 3315  spotify:track:5DeuAlTIDflXOomztXYM5D         0.794   0.730    7
# 3316  spotify:track:2X0fwXZpoAbVZdyFVjJOUm         0.539   0.909    2
# 3317  spotify:track:0PXHA9nXcu4UOJFXvye9LE         0.488   0.862    1
#
#       loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0       -5.303     0       0.0464        0.6340          0.000000    0.1160
# 1       -4.630     0       0.0474        0.1790          0.000000    0.6890
# 2       -9.222     1       0.0959        0.3710          0.000007    0.1090
# 3       -6.383     1       0.0407        0.0755          0.000000    0.2710
# 4       -5.892     0       0.0707        0.2840          0.000000    0.4050
# ...        ...   ...          ...           ...               ...       ...
# 3313   -10.121     1       0.0262        0.6240          0.000130    0.0800
# 3314   -10.763     1       0.0376        0.5370          0.006640    0.1210
# 3315    -6.067     1       0.0332        0.0538          0.000832    0.0826
# 3316    -6.546     1       0.0423        0.5180          0.000394    0.5580
# 3317    -7.653     0       0.0340        0.1690          0.025500    0.1780
#
#       valence    tempo            type                      id  \
# 0       0.437  128.945  audio_features  7dS5EaCoMnN7DzlpT6aRn2
# 1       0.625  129.965  audio_features  2V4bv1fNWfTcyRJKmej6Sj
# 2       0.620   78.558  audio_features  7KA4W4McWYRpgf0fWsJZWB
# 3       0.571  127.435  audio_features  3gbBpTdY8lnQwqxNCcf795
# 4       0.758  100.024  audio_features  3ZFTkvIE7kyPt6Nu3PEa7V
# ...       ...      ...             ...                     ...
# 3313    0.977   98.568  audio_features  6389cBCT7TWS2Nx0KVsjrk
# 3314    0.853  205.922  audio_features  2uJVtJd1w2N8vg6pJmaNdN
# 3315    0.767  128.999  audio_features  5DeuAlTIDflXOomztXYM5D
# 3316    0.964  130.821  audio_features  2X0fwXZpoAbVZdyFVjJOUm
# 3317    0.497  169.956  audio_features  0PXHA9nXcu4UOJFXvye9LE
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/7dS5EaCoMnN7...
# 1     https://api.spotify.com/v1/tracks/2V4bv1fNWfTc...
# 2     https://api.spotify.com/v1/tracks/7KA4W4McWYRp...
# 3     https://api.spotify.com/v1/tracks/3gbBpTdY8lnQ...
# 4     https://api.spotify.com/v1/tracks/3ZFTkvIE7kyP...
# ...                                                 ...
# 3313  https://api.spotify.com/v1/tracks/6389cBCT7TWS...
# 3314  https://api.spotify.com/v1/tracks/2uJVtJd1w2N8...
# 3315  https://api.spotify.com/v1/tracks/5DeuAlTIDflX...
# 3316  https://api.spotify.com/v1/tracks/2X0fwXZpoAbV...
# 3317  https://api.spotify.com/v1/tracks/0PXHA9nXcu4U...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/7dS5...       241688
# 1     https://api.spotify.com/v1/audio-analysis/2V4b...       213293
# 2     https://api.spotify.com/v1/audio-analysis/7KA4...       180387
# 3     https://api.spotify.com/v1/audio-analysis/3gbB...       214148
# 4     https://api.spotify.com/v1/audio-analysis/3ZFT...       218093
# ...                                                 ...          ...
# 3313  https://api.spotify.com/v1/audio-analysis/6389...       197760
# 3314  https://api.spotify.com/v1/audio-analysis/2uJV...       134000
# 3315  https://api.spotify.com/v1/audio-analysis/5Deu...       206640
# 3316  https://api.spotify.com/v1/audio-analysis/2X0f...       173000
# 3317  https://api.spotify.com/v1/audio-analysis/0PXH...       308773
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 3313               4
# 3314               4
# 3315               4
# 3316               4
# 3317               4
#
# [13317 rows x 20 columns]

# %%
spotify_data = spotify_data.reset_index(drop=True)

# %%
display(spotify_data.head(5), spotify_data.tail(5), spotify_data.shape)
# Out:
#                                 title              artist  \
# 0                   Take Me To Church              Hozier
# 1         Cooler Than Me - Single Mix         Mike Posner
# 2    See You Again (feat. Kali Uchis)  Tyler, The Creator
# 3                             Pompeii            Bastille
# 4  Hips Don't Lie (feat. Wyclef Jean)             Shakira
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:7dS5EaCoMnN7DzlpT6aRn2         0.566   0.664    4    -5.303
# 1  spotify:track:2V4bv1fNWfTcyRJKmej6Sj         0.768   0.820    7    -4.630
# 2  spotify:track:7KA4W4McWYRpgf0fWsJZWB         0.558   0.559    6    -9.222
# 3  spotify:track:3gbBpTdY8lnQwqxNCcf795         0.679   0.715    9    -6.383
# 4  spotify:track:3ZFTkvIE7kyPt6Nu3PEa7V         0.778   0.824   10    -5.892
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     0       0.0464        0.6340          0.000000     0.116    0.437
# 1     0       0.0474        0.1790          0.000000     0.689    0.625
# 2     1       0.0959        0.3710          0.000007     0.109    0.620
# 3     1       0.0407        0.0755          0.000000     0.271    0.571
# 4     0       0.0707        0.2840          0.000000     0.405    0.758
#
#      tempo            type                      id  \
# 0  128.945  audio_features  7dS5EaCoMnN7DzlpT6aRn2
# 1  129.965  audio_features  2V4bv1fNWfTcyRJKmej6Sj
# 2   78.558  audio_features  7KA4W4McWYRpgf0fWsJZWB
# 3  127.435  audio_features  3gbBpTdY8lnQwqxNCcf795
# 4  100.024  audio_features  3ZFTkvIE7kyPt6Nu3PEa7V
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7dS5EaCoMnN7...
# 1  https://api.spotify.com/v1/tracks/2V4bv1fNWfTc...
# 2  https://api.spotify.com/v1/tracks/7KA4W4McWYRp...
# 3  https://api.spotify.com/v1/tracks/3gbBpTdY8lnQ...
# 4  https://api.spotify.com/v1/tracks/3ZFTkvIE7kyP...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7dS5...       241688
# 1  https://api.spotify.com/v1/audio-analysis/2V4b...       213293
# 2  https://api.spotify.com/v1/audio-analysis/7KA4...       180387
# 3  https://api.spotify.com/v1/audio-analysis/3gbB...       214148
# 4  https://api.spotify.com/v1/audio-analysis/3ZFT...       218093
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#                              title         artist  \
# 13312     Jambalaya (On The Bayou)   John Fogerty
# 13313              Hearts Of Stone   John Fogerty
# 13314          Rock and Roll Girls   John Fogerty
# 13315   Rockin' All Over The World   John Fogerty
# 13316  Walking on the Chinese Wall  Philip Bailey
#
#                                         uri  danceability  energy  key  \
# 13312  spotify:track:6389cBCT7TWS2Nx0KVsjrk         0.742   0.756    2
# 13313  spotify:track:2uJVtJd1w2N8vg6pJmaNdN         0.412   0.677    6
# 13314  spotify:track:5DeuAlTIDflXOomztXYM5D         0.794   0.730    7
# 13315  spotify:track:2X0fwXZpoAbVZdyFVjJOUm         0.539   0.909    2
# 13316  spotify:track:0PXHA9nXcu4UOJFXvye9LE         0.488   0.862    1
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 13312   -10.121     1       0.0262        0.6240          0.000130    0.0800
# 13313   -10.763     1       0.0376        0.5370          0.006640    0.1210
# 13314    -6.067     1       0.0332        0.0538          0.000832    0.0826
# 13315    -6.546     1       0.0423        0.5180          0.000394    0.5580
# 13316    -7.653     0       0.0340        0.1690          0.025500    0.1780
#
#        valence    tempo            type                      id  \
# 13312    0.977   98.568  audio_features  6389cBCT7TWS2Nx0KVsjrk
# 13313    0.853  205.922  audio_features  2uJVtJd1w2N8vg6pJmaNdN
# 13314    0.767  128.999  audio_features  5DeuAlTIDflXOomztXYM5D
# 13315    0.964  130.821  audio_features  2X0fwXZpoAbVZdyFVjJOUm
# 13316    0.497  169.956  audio_features  0PXHA9nXcu4UOJFXvye9LE
#
#                                               track_href  \
# 13312  https://api.spotify.com/v1/tracks/6389cBCT7TWS...
# 13313  https://api.spotify.com/v1/tracks/2uJVtJd1w2N8...
# 13314  https://api.spotify.com/v1/tracks/5DeuAlTIDflX...
# 13315  https://api.spotify.com/v1/tracks/2X0fwXZpoAbV...
# 13316  https://api.spotify.com/v1/tracks/0PXHA9nXcu4U...
#
#                                             analysis_url  duration_ms  \
# 13312  https://api.spotify.com/v1/audio-analysis/6389...       197760
# 13313  https://api.spotify.com/v1/audio-analysis/2uJV...       134000
# 13314  https://api.spotify.com/v1/audio-analysis/5Deu...       206640
# 13315  https://api.spotify.com/v1/audio-analysis/2X0f...       173000
# 13316  https://api.spotify.com/v1/audio-analysis/0PXH...       308773
#
#        time_signature
# 13312               4
# 13313               4
# 13314               4
# 13315               4
# 13316               4
# (13317, 20)

# %%
spotify_data['uri'] = spotify_data['uri'].str.replace('spotify:track:', '')
spotify_data= spotify_data[['title', 'artist', 'uri', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'duration_ms', 'time_signature', 'id' ]]
spotify_data
# Out:
#                                     title              artist  \
# 0                       Take Me To Church              Hozier
# 1             Cooler Than Me - Single Mix         Mike Posner
# 2        See You Again (feat. Kali Uchis)  Tyler, The Creator
# 3                                 Pompeii            Bastille
# 4      Hips Don't Lie (feat. Wyclef Jean)             Shakira
# ...                                   ...                 ...
# 13312            Jambalaya (On The Bayou)        John Fogerty
# 13313                     Hearts Of Stone        John Fogerty
# 13314                 Rock and Roll Girls        John Fogerty
# 13315          Rockin' All Over The World        John Fogerty
# 13316         Walking on the Chinese Wall       Philip Bailey
#
#                           uri  danceability  energy  key  loudness  mode  \
# 0      7dS5EaCoMnN7DzlpT6aRn2         0.566   0.664    4    -5.303     0
# 1      2V4bv1fNWfTcyRJKmej6Sj         0.768   0.820    7    -4.630     0
# 2      7KA4W4McWYRpgf0fWsJZWB         0.558   0.559    6    -9.222     1
# 3      3gbBpTdY8lnQwqxNCcf795         0.679   0.715    9    -6.383     1
# 4      3ZFTkvIE7kyPt6Nu3PEa7V         0.778   0.824   10    -5.892     0
# ...                       ...           ...     ...  ...       ...   ...
# 13312  6389cBCT7TWS2Nx0KVsjrk         0.742   0.756    2   -10.121     1
# 13313  2uJVtJd1w2N8vg6pJmaNdN         0.412   0.677    6   -10.763     1
# 13314  5DeuAlTIDflXOomztXYM5D         0.794   0.730    7    -6.067     1
# 13315  2X0fwXZpoAbVZdyFVjJOUm         0.539   0.909    2    -6.546     1
# 13316  0PXHA9nXcu4UOJFXvye9LE         0.488   0.862    1    -7.653     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 0           0.0464        0.6340          0.000000    0.1160    0.437
# 1           0.0474        0.1790          0.000000    0.6890    0.625
# 2           0.0959        0.3710          0.000007    0.1090    0.620
# 3           0.0407        0.0755          0.000000    0.2710    0.571
# 4           0.0707        0.2840          0.000000    0.4050    0.758
# ...            ...           ...               ...       ...      ...
# 13312       0.0262        0.6240          0.000130    0.0800    0.977
# 13313       0.0376        0.5370          0.006640    0.1210    0.853
# 13314       0.0332        0.0538          0.000832    0.0826    0.767
# 13315       0.0423        0.5180          0.000394    0.5580    0.964
# 13316       0.0340        0.1690          0.025500    0.1780    0.497
#
#          tempo  duration_ms  time_signature                      id
# 0      128.945       241688               4  7dS5EaCoMnN7DzlpT6aRn2
# 1      129.965       213293               4  2V4bv1fNWfTcyRJKmej6Sj
# 2       78.558       180387               4  7KA4W4McWYRpgf0fWsJZWB
# 3      127.435       214148               4  3gbBpTdY8lnQwqxNCcf795
# 4      100.024       218093               4  3ZFTkvIE7kyPt6Nu3PEa7V
# ...        ...          ...             ...                     ...
# 13312   98.568       197760               4  6389cBCT7TWS2Nx0KVsjrk
# 13313  205.922       134000               4  2uJVtJd1w2N8vg6pJmaNdN
# 13314  128.999       206640               4  5DeuAlTIDflXOomztXYM5D
# 13315  130.821       173000               4  2X0fwXZpoAbVZdyFVjJOUm
# 13316  169.956       308773               4  0PXHA9nXcu4UOJFXvye9LE
#
# [13317 rows x 17 columns]

# %%
spotify_data.to_csv('spotify_data.csv', index=False)
